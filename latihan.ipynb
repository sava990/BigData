# %%
# !hdfs version
# Out:
# Hadoop 3.4.3
# Source code repository https://github.com/apache/hadoop.git -r 9d50c6884666e794e45102260a4017bb31802e1b
# Compiled by stevel on 2026-02-13T14:23Z
# Compiled on platform linux-x86_64
# Compiled with protoc 3.23.4
# From source with checksum 2331238c4c2929e66645316a32a8613
# This command was run using /home/tara/hadoop/share/hadoop/common/hadoop-common-3.4.3.jar

# %%
# !hdfs dfs -mkdir -p /user/tara/praktikum

# %%
# !hdfs dfs -ls /user/tara
# Out:
# Found 1 items
# drwxr-xr-x   - tara supergroup          0 2026-09-07 16:49 /user/tara/praktikum

# %%
with open("contoh_lokal.txt", "w") as f:
    f.write("Halo dari Praktikum Big Data!\n")
    f.write("Berkas ini awalnya tersimpan di disk lokal VM.\n")

print("Berkas lokal berhasil dibuat.")
# !ls -la contoh_lokal.txt
# Out:
# Berkas lokal berhasil dibuat.
# -rw-rw-r-- 1 tara tara 77 Sep  7 16:50 contoh_lokal.txt

# %%
# !hdfs dfs -put contoh_lokal.txt /user/tara/praktikum/

# %%
# !hdfs dfs -ls /user/tara/praktikum
# Out:
# Found 1 items
# -rw-r--r--   1 tara supergroup         77 2026-09-07 16:50 /user/tara/praktikum/contoh_lokal.txt

# %%
# !hdfs dfs -cat /user/tara/praktikum/contoh_lokal.txt
# Out:
# Halo dari Praktikum Big Data!
# Berkas ini awalnya tersimpan di disk lokal VM.

# %%
# !hdfs dfs -get /user/tara/praktikum/contoh_lokal.txt hasil_unduh_dari_hdfs.txt
# !cat hasil_unduh_dari_hdfs.txt
# Out:
# get: `hasil_unduh_dari_hdfs.txt': File exists
# Halo dari Praktikum Big Data!
# Berkas ini awalnya tersimpan di disk lokal VM.

# %%
# !hdfs dfs -du -h /user/tara/praktikum
# Out:
# 77  77  /user/tara/praktikum/contoh_lokal.txt

# %%
# !hdfs dfs -count /user/tara/praktikum
# Out:
#            1            1                 77 /user/tara/praktikum

# %%
# !hdfs dfs -mkdir -p /user/tara/latihan3

# %%
# !hdfs dfs -ls /user/tara
# Out:
# Found 2 items
# drwxr-xr-x   - tara supergroup          0 2026-09-07 17:01 /user/tara/latihan3
# drwxr-xr-x   - tara supergroup          0 2026-09-07 16:50 /user/tara/praktikum

# %%
# Menghapus satu berkas di HDFS
# !hdfs dfs -rm /user/tara/praktikum/contoh_lokal.txt

# Verifikasi berkas sudah terhapus (direktori seharusnya kosong sekarang)
# !hdfs dfs -ls /user/tara/praktikum
# Out:
# Deleted /user/tara/praktikum/contoh_lokal.txt

# %%
# !hdfs dfs -ls /user/tara
# Out:
# Found 2 items
# drwxr-xr-x   - tara supergroup          0 2026-09-07 17:01 /user/tara/latihan3
# drwxr-xr-x   - tara supergroup          0 2026-09-08 12:18 /user/tara/praktikum

# %%
with open("biodatasava.txt", "w") as f:
    f.write("Nama : Muhammad Sava Alfarisy\n")
    f.write("NIM  : 2505060029\n")
    f.write("Hobi : olahraga , oprek komputer\n")

print("Berkas lokal berhasil dibuat.")
# !ls -la biodatasava.txt
# Out:
# Berkas lokal berhasil dibuat.
# -rw-rw-r-- 1 tara tara 81 Sep  8 12:29 biodatasava.txt

# %%
# !hdfs dfs -put biodatasava.txt /user/tara/latihan3

# %%
# !hdfs dfs -ls /user/tara/latihan3
# Out:
# Found 1 items
# -rw-r--r--   1 tara supergroup         81 2026-09-08 12:30 /user/tara/latihan3/biodatasava.txt

# %%
# !hdfs dfs -cat /user/tara/latihan3/biodatasava.txt
# Out:
# Nama : Muhammad Sava Alfarisy
# NIM  : 2505060029
# Hobi : olahraga , oprek komputer
